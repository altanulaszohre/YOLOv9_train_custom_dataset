# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 18.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from ultralytics import YOLO

# %%
import yaml
config = {'path': '/content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset)',
         'train': '/content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset/train',
         'val': '/content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset/valid',
         'test': '/content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset/test',
         'nc': 8,
         'names': [ "Anger", "Contempt", "Disgust", "Fear", "Happy", "Neutral", "Sad", "Surprise"]}

with open("/content/drive/MyDrive/New_all_ai/TEST_DATASET/model_yolov9_new_3.yaml", "w+") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
model = YOLO('yolov9e.yaml')
model = YOLO('yolov9e.pt')
model.info()
results = model.train(data='/content/drive/MyDrive/New_all_ai/TEST_DATASET/model_yolov9_new_3.yaml', epochs=25, imgsz=96)
# Out:
# ...
# 100%|██████████| 112M/112M [00:00<00:00, 133MB/s]
# YOLOv9e summary: 1225 layers, 58206592 parameters, 0 gradients, 193.0 GFLOPs
# Ultralytics YOLOv8.2.0 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')

# %%
result = model('/content/drive/MyDrive/New_all_ai/TEST_DATASET/test_.jpeg')
# Out:
# image 1/1 /content/drive/MyDrive/New_all_ai/TEST_DATASET/test_.jpeg: 64x96 1 Happy, 72.0ms
# Speed: 0.7ms preprocess, 72.0ms inference, 2.3ms postprocess per image at shape (1, 3, 64, 96)

# %%
result
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Anger', 1: 'Contempt', 2: 'Disgust', 3: 'Fear', 4: 'Happy', 5: 'Neutral', 6: 'Sad', 7: 'Surprise'}
#  obb: None
#  orig_img: array([[[217, 216, 218],
#          [231, 230, 232],
#          [242, 241, 243],
#          ...,
#          [142, 145, 150],
#          [142, 145, 150],
#          [142, 145, 150]],
#
#         [[217, 216, 218],
#          [231, 230, 232],
#          [242, 241, 243],
#          ...,
#          [142, 145, 150],
#          [142, 145, 150],
#          [142, 145, 150]],
#
#         [[217, 216, 218],
#          [231, 230, 232],
#          [242, 241, 243],
#          ...,
#          [142, 145, 150],
#          [142, 145, 150],
#          [142, 145, 150]],
#
#         ...,
#
#         [[160, 164, 165],
#          [163, 167, 168],
#          [190, 194, 195],
#          ...,
#          [ 68,  57,  53],
# ...

# %%
from google.colab.patches import cv2_imshow

annotated_frame = result[0].plot()
cv2_imshow(annotated_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
result_2 = model('/content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset/test2.jpeg')
# Out:
# image 1/1 /content/drive/MyDrive/New_all_ai/TEST_DATASET/New_dataset/test2.jpeg: 64x96 1 Surprise, 48.4ms
# Speed: 0.7ms preprocess, 48.4ms inference, 1.6ms postprocess per image at shape (1, 3, 64, 96)

# %%
annotated_frame_2 = result_2[0].plot()
cv2_imshow(annotated_frame_2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>
